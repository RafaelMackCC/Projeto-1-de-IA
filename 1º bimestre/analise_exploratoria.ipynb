# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stores_data = pd.read_csv('stores.csv')
train_data = pd.read_csv('train.csv')
features_data = pd.read_csv('features.csv')

# %%
print("Stores Data")
print(stores_data.head())
# Out:
# Stores Data
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
print("\nTrain Data")
print(train_data.head())
# Out:
# Train Data
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %%
print("\nFeatures Data")
print(features_data.head())
# Out:
# Features Data
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
print("Informações Gerais das Tabelas")
print(stores_data.info())
print(train_data.info())
print(features_data.info())
# Out:
# Informações Gerais das Tabelas
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   45 non-null     int64
#  1   Type    45 non-null     object
#  2   Size    45 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# ...

# %%
# Descrever as colunas numéricas
print("\nDescrição Estatística das Colunas Numéricas")
print(train_data.describe())
# Out:
# Descrição Estatística das Colunas Numéricas
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
# Verificar se há valores ausentes
print("\nValores ausentes em Stores Data")
print(stores_data.isnull().sum())
# Out:
# Valores ausentes em Stores Data
# Store    0
# Type     0
# Size     0
# dtype: int64

# %%
print("\nValores ausentes em Train Data")
print(train_data.isnull().sum())
# Out:
# Valores ausentes em Train Data
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64

# %%
print("\nValores ausentes em Features Data")
print(features_data.isnull().sum())
# Out:
# Valores ausentes em Features Data
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %%
import pandas as pd

# Converção de objetos
train_data['Date'] = pd.to_datetime(train_data['Date'])

# Extrair numeros do date
train_data['WeekOfYear'] = train_data['Date'].dt.isocalendar().week

#Calcular correlações
print("\nCorrelação entre as variáveis numéricas do dataset de treino")
print(train_data.drop(columns=['Date']).corr())
# Out:
# Correlação entre as variáveis numéricas do dataset de treino
#                  Store      Dept  Weekly_Sales  IsHoliday  WeekOfYear
# Store         1.000000  0.024004     -0.085195  -0.000548    0.001031
# Dept          0.024004  1.000000      0.148032   0.000916    0.000882
# Weekly_Sales -0.085195  0.148032      1.000000   0.012774    0.027673
# IsHoliday    -0.000548  0.000916      0.012774   1.000000    0.128184
# WeekOfYear    0.001031  0.000882      0.027673   0.128184    1.000000

# %%
# Explorar as correlações entre as variáveis
print("\nCorrelação entre as variáveis numéricas do dataset de treino")
print(train_data.corr())
# Out:
# Correlação entre as variáveis numéricas do dataset de treino
#                  Store      Dept      Date  Weekly_Sales  IsHoliday  \
# Store         1.000000  0.024004  0.003362     -0.085195  -0.000548
# Dept          0.024004  1.000000  0.004054      0.148032   0.000916
# Date          0.003362  0.004054  1.000000     -0.000663  -0.013017
# Weekly_Sales -0.085195  0.148032 -0.000663      1.000000   0.012774
# IsHoliday    -0.000548  0.000916 -0.013017      0.012774   1.000000
# WeekOfYear    0.001031  0.000882  0.160332      0.027673   0.128184
#
#               WeekOfYear
# Store           0.001031
# Dept            0.000882
# Date            0.160332
# Weekly_Sales    0.027673
# IsHoliday       0.128184
# WeekOfYear      1.000000

# %%
sns.histplot(train_data['Weekly_Sales'], bins=50, kde=True)
plt.title('Distribuição de Vendas Semanais')
plt.show()

# Visualizar correlação entre as variáveis
plt.figure(figsize=(10,8))
sns.heatmap(train_data.corr(), annot=True, cmap='coolwarm')
plt.title('Mapa de Calor das Correlações')
plt.show()
